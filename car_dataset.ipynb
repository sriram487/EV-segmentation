# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv(r"C:\Users\sriram\Desktop\EV_Datasets\Vehicle Datasets\\Car details v3.csv")

# %%
data.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
data.selling_price.value_counts(normalize=True)
# Out:
# 300000     0.027928
# 600000     0.026206
# 350000     0.025714
# 550000     0.025098
# 450000     0.023991
#              ...
# 808000     0.000123
# 92000      0.000123
# 731000     0.000123
# 1365000    0.000123
# 1237000    0.000123
# Name: selling_price, Length: 677, dtype: float64

# %%
sns.pairplot(data = data, vars=['selling_price','km_driven','year'])
plt.show()

# %%
data[['selling_price','km_driven','year']].corr()


sns.heatmap(data[['selling_price','km_driven','year']].corr(), annot=True, cmap = 'Reds')
plt.show()
